# %%
import pandas as pd
import os
# os.chdir("/Users/r.swift/Documents/LearningAndDevelopment/DataLaunchPad/datalaunchpad-project")

# %%
september_22 = pd.read_parquet("yellow_tripdata_2022-09.parquet")
ny_taxi_zones = pd.read_csv("taxi_zones.csv")

# %% [markdown]
# # Data Exploration
# ## Data cleaning
# - Remove duplicates,
# - check for missing values,
# - check for 0s and NaNs,
# - format dates,
# - cast types as expected,
# - check for valid dates

# %%
september_22
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2022-09-01 00:28:12   2022-09-01 00:36:22              1.0
# 1               1  2022-09-01 00:51:58   2022-09-01 01:14:43              1.0
# 2               1  2022-09-01 00:08:29   2022-09-01 00:26:29              1.0
# 3               2  2022-09-01 00:02:24   2022-09-01 00:09:39              1.0
# 4               2  2022-09-01 00:47:25   2022-09-01 00:56:09              1.0
# ...           ...                  ...                   ...              ...
# 3183762         2  2022-09-30 23:46:31   2022-10-01 00:04:50              NaN
# 3183763         2  2022-09-30 23:43:29   2022-09-30 23:59:16              NaN
# 3183764         2  2022-09-30 23:45:30   2022-09-30 23:59:13              NaN
# 3183765         2  2022-09-30 23:09:37   2022-09-30 23:21:28              NaN
# 3183766         2  2022-09-30 23:49:00   2022-10-01 00:17:00              NaN
#
# ...

# %% [markdown]
# ### Column
# #### VendorID
# 1= Creative Mobile Technologies, LLC; 2= VeriFone Inc.

# %%
september_22.drop_duplicates(inplace=True)
september_22['passenger_count'].isna().sum() # NUmber of NAs: 116592
# Out:
# 0

# %% [markdown]
# # Project Idea
# Tip prediction
# Initially based on the pick up and drop off locaiton of the journey
# Would then like to bring in external weather data and see how this effects the tips

# %%
# Out:
# hi

# %%
len(parquet_data['tip_amount'].unique())
# Out:
# 3683
